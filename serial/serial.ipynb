# %%
import sys
sys.path.append('..')
from importlib import reload
from utils import txt_to_nparray, visualization, check
reload(txt_to_nparray)
reload(visualization)
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
dataset = txt_to_nparray.read_txt_file('../dataset/birch/birch3.txt')
dataset = dataset[0:]
plt.scatter(dataset[:,0], dataset[:,1], s=1)

# %%
from serial import dbscan
reload(dbscan)
# Out:
# <module 'serial.dbscan' from '/Users/apple/MSBD5003Project/serial/../serial/dbscan.py'>

# %%
MIN_PTS = 4
NOISE_LABEL = -2

start_time = time.time()
pred_labels = dbscan.dbscan(dataset, 900, MIN_PTS)
print(f'time used: {time.time() - start_time}')

check.check_cluster_number(pred_labels, MIN_PTS)

# %%
from sklearn.cluster import DBSCAN
MIN_PTS = 3
start_time = time.time()
cluster = DBSCAN(eps=4000, min_samples=MIN_PTS).fit(dataset)
print(f'time used: {time.time() - start_time}')
# Out:
# time used: 1.0458958148956299

# %%
reload(visualization)
visualization.visualize_dataset_with_label(dataset, cluster.labels_, noise_label=-1)

# %%
reload(visualization)
print(set(pred_labels))
visualization.visualize_dataset_with_label(dataset, pred_labels, noise_label=NOISE_LABEL)
# Out:
# {1, 2, 3, 4, 5, -2}
